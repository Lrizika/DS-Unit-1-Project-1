# %%
import pandas
import matplotlib.pyplot as pyplot

df = pandas.read_csv('browser-ww-monthly-200901-201909.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-438276a7b8f9> in <module>
#       3 import matplotlib.pyplot as pyplot
#       4
# ----> 5 df = pandas.read_csv('browser-ww-monthly-200901-201909.csv')
#       6 df.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'browser-ww-monthly-200901-201909.csv' does not exist: b'browser-ww-monthly-200901-201909.csv'

# %%
import pandas
import matplotlib.pyplot as pyplot

df = pandas.read_csv('./data/browser-ww-monthly-200901-201909.csv')
df.head()
# Out:
#       Date  Chrome     IE  Firefox  Safari  Opera  Android  UC Browser  \
# 0  2009-01    1.37  64.97    26.85    2.79   3.07     0.01         0.0
# 1  2009-02    1.50  63.98    27.66    2.83   3.09     0.01         0.0
# 2  2009-03    1.71  62.02    29.17    3.02   3.09     0.02         0.0
# 3  2009-04    2.05  61.34    29.41    3.09   3.12     0.02         0.0
# 4  2009-05    2.40  61.55    28.50    2.95   3.41     0.02         0.0
#
#    Samsung Internet  Nokia  ...   AOL  SeaMonkey  Openwave  Phantom  \
# 0               0.0   0.12  ...  0.27       0.04      0.02      0.0
# 1               0.0   0.13  ...  0.26       0.03      0.02      0.0
# 2               0.0   0.14  ...  0.25       0.03      0.02      0.0
# 3               0.0   0.14  ...  0.23       0.03      0.02      0.0
# 4               0.0   0.15  ...  0.21       0.03      0.02      0.0
#
#    SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# 0          0.02    0.0      0.0        0.0       0.0   0.20
# 1          0.02    0.0      0.0        0.0       0.0   0.19
# 2          0.03    0.0      0.0        0.0       0.0   0.19
# 3          0.03    0.0      0.0        0.0       0.0   0.17
# 4          0.03    0.0      0.0        0.0       0.0   0.18
#
# [5 rows x 40 columns]

# %%
df.tail()
# Out:
#         Date  Chrome    IE  Firefox  Safari  Opera  Android  UC Browser  \
# 124  2019-05   62.98  2.46     5.01   15.74   2.54     0.91        3.13
# 125  2019-06   63.69  2.29     4.64   15.15   2.53     1.00        3.32
# 126  2019-07   63.37  2.26     4.49   15.05   2.58     0.97        3.57
# 127  2019-08   63.99  1.97     4.44   15.48   2.65     0.73        3.46
# 128  2019-09   63.87  2.23     4.49   16.11   2.51     0.61        3.17
#
#      Samsung Internet  Nokia  ...  AOL  SeaMonkey  Openwave  Phantom  \
# 124              3.40   0.01  ...  0.0       0.00       0.0      0.0
# 125              3.53   0.01  ...  0.0       0.01       0.0      0.0
# 126              3.75   0.01  ...  0.0       0.01       0.0      0.0
# 127              3.49   0.01  ...  0.0       0.00       0.0      0.0
# 128              3.32   0.01  ...  0.0       0.00       0.0      0.0
#
#      SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# 124           0.0    0.0      0.0       0.01       0.0   0.16
# 125           0.0    0.0      0.0       0.01       0.0   0.16
# 126           0.0    0.0      0.0       0.01       0.0   0.15
# 127           0.0    0.0      0.0       0.01       0.0   0.15
# 128           0.0    0.0      0.0       0.01       0.0   0.15
#
# [5 rows x 40 columns]

# %%
df.reindex(columns=['Date'])
# Out:
#         Date
# 0    2009-01
# 1    2009-02
# 2    2009-03
# 3    2009-04
# 4    2009-05
# ..       ...
# 124  2019-05
# 125  2019-06
# 126  2019-07
# 127  2019-08
# 128  2019-09
#
# [129 rows x 1 columns]

# %%
df.head()
# Out:
#       Date  Chrome     IE  Firefox  Safari  Opera  Android  UC Browser  \
# 0  2009-01    1.37  64.97    26.85    2.79   3.07     0.01         0.0
# 1  2009-02    1.50  63.98    27.66    2.83   3.09     0.01         0.0
# 2  2009-03    1.71  62.02    29.17    3.02   3.09     0.02         0.0
# 3  2009-04    2.05  61.34    29.41    3.09   3.12     0.02         0.0
# 4  2009-05    2.40  61.55    28.50    2.95   3.41     0.02         0.0
#
#    Samsung Internet  Nokia  ...   AOL  SeaMonkey  Openwave  Phantom  \
# 0               0.0   0.12  ...  0.27       0.04      0.02      0.0
# 1               0.0   0.13  ...  0.26       0.03      0.02      0.0
# 2               0.0   0.14  ...  0.25       0.03      0.02      0.0
# 3               0.0   0.14  ...  0.23       0.03      0.02      0.0
# 4               0.0   0.15  ...  0.21       0.03      0.02      0.0
#
#    SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# 0          0.02    0.0      0.0        0.0       0.0   0.20
# 1          0.02    0.0      0.0        0.0       0.0   0.19
# 2          0.03    0.0      0.0        0.0       0.0   0.19
# 3          0.03    0.0      0.0        0.0       0.0   0.17
# 4          0.03    0.0      0.0        0.0       0.0   0.18
#
# [5 rows x 40 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=129, step=1)

# %%
df.reindex(index=['Date'])
# Out:
#      Date  Chrome  IE  Firefox  Safari  Opera  Android  UC Browser  \
# Date  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
#
#       Samsung Internet  Nokia  ...  AOL  SeaMonkey  Openwave  Phantom  \
# Date               NaN    NaN  ...  NaN        NaN       NaN      NaN
#
#       SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# Date           NaN    NaN      NaN        NaN       NaN    NaN
#
# [1 rows x 40 columns]

# %%
df.reindex(index='Date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b29682d9019a> in <module>
#       1 #%%
# ----> 2 df.reindex(index='Date')
#
# /usr/local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3959         kwargs.pop("axis", None)
#    3960         kwargs.pop("labels", None)
# -> 3961         return super().reindex(**kwargs)
#    3962
#    3963     def drop(
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3847         if index is not None:
#    3848             frame = frame._reindex_index(
# -> 3849                 index, method, copy, level, fill_value, limit, tolerance
#    3850             )
#    3851
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3863     ):
#    3864         new_index, indexer = self.index.reindex(
# -> 3865             new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    3866         )
#    3867         return self._reindex_with_indexers(
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3391             target = self._simple_new(values, dtype=self.dtype, **attrs)
#    3392         else:
# -> 3393             target = ensure_index(target)
#    3394
#    3395         if level is not None:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5769             index_like = copy(index_like)
#    5770
# -> 5771     return Index(index_like)
#    5772
#    5773
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     517             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#     518         elif data is None or is_scalar(data):
# --> 519             cls._scalar_data_error(data)
#     520         else:
#     521             if tupleize_cols and is_list_like(data):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#    4106         raise TypeError(
#    4107             "{0}(...) must be called with a collection of some "
# -> 4108             "kind, {1} was passed".format(cls.__name__, repr(data))
#    4109         )
#    4110
#
# TypeError: Index(...) must be called with a collection of some kind, 'Date' was passed

# %%
df.reindex(index=df['Date'])
# Out:
#         Date  Chrome  IE  Firefox  Safari  Opera  Android  UC Browser  \
# Date
# 2009-01  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2009-02  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2009-03  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2009-04  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2009-05  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# ...      ...     ...  ..      ...     ...    ...      ...         ...
# 2019-05  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2019-06  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2019-07  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2019-08  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
# 2019-09  NaN     NaN NaN      NaN     NaN    NaN      NaN         NaN
#
#          Samsung Internet  Nokia  ...  AOL  SeaMonkey  Openwave  Phantom  \
# Date                              ...
# 2009-01               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2009-02               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2009-03               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2009-04               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2009-05               NaN    NaN  ...  NaN        NaN       NaN      NaN
# ...                   ...    ...  ...  ...        ...       ...      ...
# 2019-05               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2019-06               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2019-07               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2019-08               NaN    NaN  ...  NaN        NaN       NaN      NaN
# 2019-09               NaN    NaN  ...  NaN        NaN       NaN      NaN
#
#          SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# Date
# 2009-01           NaN    NaN      NaN        NaN       NaN    NaN
# 2009-02           NaN    NaN      NaN        NaN       NaN    NaN
# 2009-03           NaN    NaN      NaN        NaN       NaN    NaN
# 2009-04           NaN    NaN      NaN        NaN       NaN    NaN
# 2009-05           NaN    NaN      NaN        NaN       NaN    NaN
# ...               ...    ...      ...        ...       ...    ...
# 2019-05           NaN    NaN      NaN        NaN       NaN    NaN
# 2019-06           NaN    NaN      NaN        NaN       NaN    NaN
# 2019-07           NaN    NaN      NaN        NaN       NaN    NaN
# 2019-08           NaN    NaN      NaN        NaN       NaN    NaN
# 2019-09           NaN    NaN      NaN        NaN       NaN    NaN
#
# [129 rows x 40 columns]

# %%
df.index=df['Date']

# %%
df.head()
# Out:
#             Date  Chrome     IE  Firefox  Safari  Opera  Android  UC Browser  \
# Date
# 2009-01  2009-01    1.37  64.97    26.85    2.79   3.07     0.01         0.0
# 2009-02  2009-02    1.50  63.98    27.66    2.83   3.09     0.01         0.0
# 2009-03  2009-03    1.71  62.02    29.17    3.02   3.09     0.02         0.0
# 2009-04  2009-04    2.05  61.34    29.41    3.09   3.12     0.02         0.0
# 2009-05  2009-05    2.40  61.55    28.50    2.95   3.41     0.02         0.0
#
#          Samsung Internet  Nokia  ...   AOL  SeaMonkey  Openwave  Phantom  \
# Date                              ...
# 2009-01               0.0   0.12  ...  0.27       0.04      0.02      0.0
# 2009-02               0.0   0.13  ...  0.26       0.03      0.02      0.0
# 2009-03               0.0   0.14  ...  0.25       0.03      0.02      0.0
# 2009-04               0.0   0.14  ...  0.23       0.03      0.02      0.0
# 2009-05               0.0   0.15  ...  0.21       0.03      0.02      0.0
#
#          SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# Date
# 2009-01          0.02    0.0      0.0        0.0       0.0   0.20
# 2009-02          0.02    0.0      0.0        0.0       0.0   0.19
# 2009-03          0.03    0.0      0.0        0.0       0.0   0.19
# 2009-04          0.03    0.0      0.0        0.0       0.0   0.17
# 2009-05          0.03    0.0      0.0        0.0       0.0   0.18
#
# [5 rows x 40 columns]

# %%
df.index=df['Date']

df = df.drop('Date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7c94402ee621> in <module>
#       2 df.index=df['Date']
#       3
# ----> 4 df = df.drop('Date')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Date'] not found in axis"

# %%
df.index=df['Date']

df = df.drop(columns=['Date'])

# %%
df.head()
# Out:
#          Chrome     IE  Firefox  Safari  Opera  Android  UC Browser  \
# Date
# 2009-01    1.37  64.97    26.85    2.79   3.07     0.01         0.0
# 2009-02    1.50  63.98    27.66    2.83   3.09     0.01         0.0
# 2009-03    1.71  62.02    29.17    3.02   3.09     0.02         0.0
# 2009-04    2.05  61.34    29.41    3.09   3.12     0.02         0.0
# 2009-05    2.40  61.55    28.50    2.95   3.41     0.02         0.0
#
#          Samsung Internet  Nokia  Edge  ...   AOL  SeaMonkey  Openwave  \
# Date                                    ...
# 2009-01               0.0   0.12   0.0  ...  0.27       0.04      0.02
# 2009-02               0.0   0.13   0.0  ...  0.26       0.03      0.02
# 2009-03               0.0   0.14   0.0  ...  0.25       0.03      0.02
# 2009-04               0.0   0.14   0.0  ...  0.23       0.03      0.02
# 2009-05               0.0   0.15   0.0  ...  0.21       0.03      0.02
#
#          Phantom  SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# Date
# 2009-01      0.0          0.02    0.0      0.0        0.0       0.0   0.20
# 2009-02      0.0          0.02    0.0      0.0        0.0       0.0   0.19
# 2009-03      0.0          0.03    0.0      0.0        0.0       0.0   0.19
# 2009-04      0.0          0.03    0.0      0.0        0.0       0.0   0.17
# 2009-05      0.0          0.03    0.0      0.0        0.0       0.0   0.18
#
# [5 rows x 39 columns]

# %%
import pandas

df = pandas.read_csv('./data/browser-ww-monthly-200901-201909.csv')
df.head()
# Out:
#       Date  Chrome     IE  Firefox  Safari  Opera  Android  UC Browser  \
# 0  2009-01    1.37  64.97    26.85    2.79   3.07     0.01         0.0
# 1  2009-02    1.50  63.98    27.66    2.83   3.09     0.01         0.0
# 2  2009-03    1.71  62.02    29.17    3.02   3.09     0.02         0.0
# 3  2009-04    2.05  61.34    29.41    3.09   3.12     0.02         0.0
# 4  2009-05    2.40  61.55    28.50    2.95   3.41     0.02         0.0
#
#    Samsung Internet  Nokia  ...   AOL  SeaMonkey  Openwave  Phantom  \
# 0               0.0   0.12  ...  0.27       0.04      0.02      0.0
# 1               0.0   0.13  ...  0.26       0.03      0.02      0.0
# 2               0.0   0.14  ...  0.25       0.03      0.02      0.0
# 3               0.0   0.14  ...  0.23       0.03      0.02      0.0
# 4               0.0   0.15  ...  0.21       0.03      0.02      0.0
#
#    SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# 0          0.02    0.0      0.0        0.0       0.0   0.20
# 1          0.02    0.0      0.0        0.0       0.0   0.19
# 2          0.03    0.0      0.0        0.0       0.0   0.19
# 3          0.03    0.0      0.0        0.0       0.0   0.17
# 4          0.03    0.0      0.0        0.0       0.0   0.18
#
# [5 rows x 40 columns]

# %%
df.tail()
# Out:
#         Date  Chrome    IE  Firefox  Safari  Opera  Android  UC Browser  \
# 124  2019-05   62.98  2.46     5.01   15.74   2.54     0.91        3.13
# 125  2019-06   63.69  2.29     4.64   15.15   2.53     1.00        3.32
# 126  2019-07   63.37  2.26     4.49   15.05   2.58     0.97        3.57
# 127  2019-08   63.99  1.97     4.44   15.48   2.65     0.73        3.46
# 128  2019-09   63.87  2.23     4.49   16.11   2.51     0.61        3.17
#
#      Samsung Internet  Nokia  ...  AOL  SeaMonkey  Openwave  Phantom  \
# 124              3.40   0.01  ...  0.0       0.00       0.0      0.0
# 125              3.53   0.01  ...  0.0       0.01       0.0      0.0
# 126              3.75   0.01  ...  0.0       0.01       0.0      0.0
# 127              3.49   0.01  ...  0.0       0.00       0.0      0.0
# 128              3.32   0.01  ...  0.0       0.00       0.0      0.0
#
#      SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# 124           0.0    0.0      0.0       0.01       0.0   0.16
# 125           0.0    0.0      0.0       0.01       0.0   0.16
# 126           0.0    0.0      0.0       0.01       0.0   0.15
# 127           0.0    0.0      0.0       0.01       0.0   0.15
# 128           0.0    0.0      0.0       0.01       0.0   0.15
#
# [5 rows x 40 columns]

# %%
df.index=df['Date']

# df = df.drop(columns=['Date'])

# %%
import matplotlib.pyplot as pyplot
pyplot.rcParams['figure.facecolor'] = '#002B3600'
pyplot.rcParams['axes.facecolor'] = '#00000000'
COLOR = 'black'
pyplot.rcParams['text.color'] = COLOR
pyplot.rcParams['axes.labelcolor'] = COLOR
pyplot.rcParams['xtick.color'] = COLOR
pyplot.rcParams['ytick.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['grid.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['legend.facecolor'] = '#ffffff19'
# pyplot.rcParams['figure.edgecolor'] = COLOR
pyplot.rcParams['axes.edgecolor'] = COLOR

d = {'Chrome':  'b',
	'Firefox': 'r',
	'Internet Explorer': 'black',
	'Safari': 'g',
	'Edge': 'magenta'}
for browser in d:
	pyplot.plot(df.index, df[browser], d[browser], label=browser)
# pyplot.plot(ie_points, color='turquoise', label='Internet Explorer')
# pyplot.plot(firefox_points, color='r', label='Firefox')
# pyplot.plot(chrome_points, color='b', label='Chrome')
# pyplot.plot(safari_points, color='g', label='Safari')
# pyplot.plot(edge_points, color='magenta', label='Edge')
pyplot.legend()
pyplot.title('CVEs by year for different browsers, by CVE ID')
pyplot.xlabel('Year')
pyplot.ylabel('Number of CVEs')
pyplot.grid()
figure = pyplot.gcf()
figure.set_size_inches((12,10))
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Internet Explorer'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-685738e9b49c> in <module>
#      21 	'Edge': 'magenta'}
#      22 for browser in d:
# ---> 23         pyplot.plot(df.index, df[browser], d[browser], label=browser)
#      24 # pyplot.plot(ie_points, color='turquoise', label='Internet Explorer')
#      25 # pyplot.plot(firefox_points, color='r', label='Firefox')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Internet Explorer'

# %%
import pandas

df = pandas.read_csv('./data/browser-ww-monthly-200901-201909.csv')
df.head()
# Out:
#       Date  Chrome     IE  Firefox  Safari  Opera  Android  UC Browser  \
# 0  2009-01    1.37  64.97    26.85    2.79   3.07     0.01         0.0
# 1  2009-02    1.50  63.98    27.66    2.83   3.09     0.01         0.0
# 2  2009-03    1.71  62.02    29.17    3.02   3.09     0.02         0.0
# 3  2009-04    2.05  61.34    29.41    3.09   3.12     0.02         0.0
# 4  2009-05    2.40  61.55    28.50    2.95   3.41     0.02         0.0
#
#    Samsung Internet  Nokia  ...   AOL  SeaMonkey  Openwave  Phantom  \
# 0               0.0   0.12  ...  0.27       0.04      0.02      0.0
# 1               0.0   0.13  ...  0.26       0.03      0.02      0.0
# 2               0.0   0.14  ...  0.25       0.03      0.02      0.0
# 3               0.0   0.14  ...  0.23       0.03      0.02      0.0
# 4               0.0   0.15  ...  0.21       0.03      0.02      0.0
#
#    SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# 0          0.02    0.0      0.0        0.0       0.0   0.20
# 1          0.02    0.0      0.0        0.0       0.0   0.19
# 2          0.03    0.0      0.0        0.0       0.0   0.19
# 3          0.03    0.0      0.0        0.0       0.0   0.17
# 4          0.03    0.0      0.0        0.0       0.0   0.18
#
# [5 rows x 40 columns]

# %%
df.tail()
# Out:
#         Date  Chrome    IE  Firefox  Safari  Opera  Android  UC Browser  \
# 124  2019-05   62.98  2.46     5.01   15.74   2.54     0.91        3.13
# 125  2019-06   63.69  2.29     4.64   15.15   2.53     1.00        3.32
# 126  2019-07   63.37  2.26     4.49   15.05   2.58     0.97        3.57
# 127  2019-08   63.99  1.97     4.44   15.48   2.65     0.73        3.46
# 128  2019-09   63.87  2.23     4.49   16.11   2.51     0.61        3.17
#
#      Samsung Internet  Nokia  ...  AOL  SeaMonkey  Openwave  Phantom  \
# 124              3.40   0.01  ...  0.0       0.00       0.0      0.0
# 125              3.53   0.01  ...  0.0       0.01       0.0      0.0
# 126              3.75   0.01  ...  0.0       0.01       0.0      0.0
# 127              3.49   0.01  ...  0.0       0.00       0.0      0.0
# 128              3.32   0.01  ...  0.0       0.00       0.0      0.0
#
#      SonyEricsson  Obigo  Jasmine  Pale Moon  RockMelt  Other
# 124           0.0    0.0      0.0       0.01       0.0   0.16
# 125           0.0    0.0      0.0       0.01       0.0   0.16
# 126           0.0    0.0      0.0       0.01       0.0   0.15
# 127           0.0    0.0      0.0       0.01       0.0   0.15
# 128           0.0    0.0      0.0       0.01       0.0   0.15
#
# [5 rows x 40 columns]

# %%
df.index=df['Date']

# df = df.drop(columns=['Date'])

# %%
import matplotlib.pyplot as pyplot
pyplot.rcParams['figure.facecolor'] = '#002B3600'
pyplot.rcParams['axes.facecolor'] = '#00000000'
COLOR = 'black'
pyplot.rcParams['text.color'] = COLOR
pyplot.rcParams['axes.labelcolor'] = COLOR
pyplot.rcParams['xtick.color'] = COLOR
pyplot.rcParams['ytick.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['grid.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['legend.facecolor'] = '#ffffff19'
# pyplot.rcParams['figure.edgecolor'] = COLOR
pyplot.rcParams['axes.edgecolor'] = COLOR

d = {'Chrome':  'b',
	'Firefox': 'r',
	'IE': 'black',
	'Safari': 'g',
	'Edge': 'magenta'}
for browser in d:
	pyplot.plot(df.index, df[browser], d[browser], label=browser)
# pyplot.plot(ie_points, color='turquoise', label='Internet Explorer')
# pyplot.plot(firefox_points, color='r', label='Firefox')
# pyplot.plot(chrome_points, color='b', label='Chrome')
# pyplot.plot(safari_points, color='g', label='Safari')
# pyplot.plot(edge_points, color='magenta', label='Edge')
pyplot.legend()
pyplot.title('CVEs by year for different browsers, by CVE ID')
pyplot.xlabel('Year')
pyplot.ylabel('Number of CVEs')
pyplot.grid()
figure = pyplot.gcf()
figure.set_size_inches((12,10))
pyplot.show()

# %%
import matplotlib.pyplot as pyplot
pyplot.rcParams['figure.facecolor'] = '#002B3600'
pyplot.rcParams['axes.facecolor'] = '#00000000'
COLOR = 'black'
pyplot.rcParams['text.color'] = COLOR
pyplot.rcParams['axes.labelcolor'] = COLOR
pyplot.rcParams['xtick.color'] = COLOR
pyplot.rcParams['ytick.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['grid.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['legend.facecolor'] = '#ffffff19'
# pyplot.rcParams['figure.edgecolor'] = COLOR
pyplot.rcParams['axes.edgecolor'] = COLOR

d = {'Chrome':  'b',
	'Firefox': 'r',
	'IE': 'black',
	'Safari': 'g',
	'Edge': 'magenta'}
for browser in d:
	pyplot.plot(df.index, df[browser], d[browser], label=browser)
# pyplot.plot(ie_points, color='turquoise', label='Internet Explorer')
# pyplot.plot(firefox_points, color='r', label='Firefox')
# pyplot.plot(chrome_points, color='b', label='Chrome')
# pyplot.plot(safari_points, color='g', label='Safari')
# pyplot.plot(edge_points, color='magenta', label='Edge')
pyplot.legend()
pyplot.title('CVEs by year for different browsers, by CVE ID')
pyplot.xlabel('Year')
pyplot.ylabel('Number of CVEs')
ax = pyplot.gcf().axes[0]
ax.set_xticks(ax.get_xticks()[::5])
pyplot.grid()
figure = pyplot.gcf()
figure.set_size_inches((12,10))
pyplot.show()

# %%
import matplotlib.pyplot as pyplot
pyplot.rcParams['figure.facecolor'] = '#002B3600'
pyplot.rcParams['axes.facecolor'] = '#00000000'
COLOR = 'black'
pyplot.rcParams['text.color'] = COLOR
pyplot.rcParams['axes.labelcolor'] = COLOR
pyplot.rcParams['xtick.color'] = COLOR
pyplot.rcParams['ytick.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['grid.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['legend.facecolor'] = '#ffffff19'
# pyplot.rcParams['figure.edgecolor'] = COLOR
pyplot.rcParams['axes.edgecolor'] = COLOR

d = {'Chrome':  'b',
	'Firefox': 'r',
	'IE': 'black',
	'Safari': 'g',
	'Edge': 'magenta'}
for browser in d:
	pyplot.plot(df.index, df[browser], d[browser], label=browser)
# pyplot.plot(ie_points, color='turquoise', label='Internet Explorer')
# pyplot.plot(firefox_points, color='r', label='Firefox')
# pyplot.plot(chrome_points, color='b', label='Chrome')
# pyplot.plot(safari_points, color='g', label='Safari')
# pyplot.plot(edge_points, color='magenta', label='Edge')
pyplot.legend()
pyplot.title('CVEs by year for different browsers, by CVE ID')
pyplot.xlabel('Year')
pyplot.ylabel('Number of CVEs')
ax = pyplot.gcf().axes[0]
ax.set_xticks(ax.get_xticks()[::8])
pyplot.grid()
figure = pyplot.gcf()
figure.set_size_inches((12,10))
pyplot.show()

# %%
import matplotlib.pyplot as pyplot
pyplot.rcParams['figure.facecolor'] = '#002B3600'
pyplot.rcParams['axes.facecolor'] = '#00000000'
COLOR = 'black'
pyplot.rcParams['text.color'] = COLOR
pyplot.rcParams['axes.labelcolor'] = COLOR
pyplot.rcParams['xtick.color'] = COLOR
pyplot.rcParams['ytick.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['grid.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['legend.facecolor'] = '#ffffff19'
# pyplot.rcParams['figure.edgecolor'] = COLOR
pyplot.rcParams['axes.edgecolor'] = COLOR

d = {'Chrome':  'b',
	'Firefox': 'r',
	'IE': 'black',
	'Safari': 'g',
	'Edge': 'magenta'}
for browser in d:
	pyplot.plot(df.index, df[browser], d[browser], label=browser)
# pyplot.plot(ie_points, color='turquoise', label='Internet Explorer')
# pyplot.plot(firefox_points, color='r', label='Firefox')
# pyplot.plot(chrome_points, color='b', label='Chrome')
# pyplot.plot(safari_points, color='g', label='Safari')
# pyplot.plot(edge_points, color='magenta', label='Edge')
pyplot.legend()
pyplot.title('CVEs by year for different browsers, by CVE ID')
pyplot.xlabel('Year')
pyplot.ylabel('Number of CVEs')
ax = pyplot.gcf().axes[0]
ax.set_xticks(ax.get_xticks()[::12])
pyplot.grid()
figure = pyplot.gcf()
figure.set_size_inches((12,10))
pyplot.show()

# %%
import matplotlib.pyplot as pyplot
pyplot.rcParams['figure.facecolor'] = '#002B3600'
pyplot.rcParams['axes.facecolor'] = '#00000000'
COLOR = 'black'
pyplot.rcParams['text.color'] = COLOR
pyplot.rcParams['axes.labelcolor'] = COLOR
pyplot.rcParams['xtick.color'] = COLOR
pyplot.rcParams['ytick.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['grid.color'] = COLOR
pyplot.rcParams['lines.color'] = COLOR
pyplot.rcParams['legend.facecolor'] = '#ffffff19'
# pyplot.rcParams['figure.edgecolor'] = COLOR
pyplot.rcParams['axes.edgecolor'] = COLOR

d = {'Chrome':  'b',
	'Firefox': 'r',
	'IE': 'black',
	'Safari': 'g',
	'Edge': 'magenta'}
for browser in d:
	pyplot.plot(df.index, df[browser], d[browser], label=browser)
# pyplot.plot(ie_points, color='turquoise', label='Internet Explorer')
# pyplot.plot(firefox_points, color='r', label='Firefox')
# pyplot.plot(chrome_points, color='b', label='Chrome')
# pyplot.plot(safari_points, color='g', label='Safari')
# pyplot.plot(edge_points, color='magenta', label='Edge')
pyplot.legend()
pyplot.title('Browser share')
pyplot.xlabel('Year')
pyplot.ylabel('Share (%)')
ax = pyplot.gcf().axes[0]
ax.set_xticks(ax.get_xticks()[::12])
pyplot.grid()
figure = pyplot.gcf()
figure.set_size_inches((12,10))
pyplot.show()
